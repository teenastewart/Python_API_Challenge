# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
from citipy import citipy
from random import uniform
from config import api_key
import numpy as np
import pandas as pd
import requests
import csv
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generate Cities List

# %%
cities = []
# generate more than 500 to cover duplicates and errors
while len(cities) < 600:
    lat = round(uniform(-90, 90), 3)
    long = round(uniform(-180, 180), 3)
    city = citipy.nearest_city(lat,long)
    city_name = city.city_name
    country_code = city.country_code
    city_vals = f"{city_name}, {country_code}"
    # add cities to list
    if city_vals not in cities:
        cities.append(city_vals)
        print(f"{city_vals} added to list.")
len(cities)
# Out:
# susanville, us added to list.
# port alfred, za added to list.
# rikitea, pf added to list.
# korgen, no added to list.
# albany, au added to list.
# saskylakh, ru added to list.
# arrifes, pt added to list.
# east london, za added to list.
# bambous virieux, mu added to list.
# meyungs, pw added to list.
# vila franca do campo, pt added to list.
# codrington, ag added to list.
# dothan, us added to list.
# avarua, ck added to list.
# saint-philippe, re added to list.
# ushuaia, ar added to list.
# vaini, to added to list.
# rocha, uy added to list.
# calatayud, es added to list.
# atuona, pf added to list.
# sechura, pe added to list.
# montepuez, mz added to list.
# new norfolk, au added to list.
# barentsburg, sj added to list.
# cape town, za added to list.
# san cristobal, ec added to list.
# punta arenas, cl added to list.
# los llanos de aridane, es added to list.
# bluff, nz added to list.
# mataura, pf added to list.
# nanortalik, gl added to list.
# sitka, us added to list.
# puerto ayora, ec added to list.
# pedernales, do added to list.
# ouango, cf added to list.
# tasiilaq, gl added to list.
# busselton, au added to list.
# taolanaro, mg added to list.
# vallenar, cl added to list.
# hamilton, bm added to list.
# govindgarh, in added to list.
# nome, us added to list.
# faanui, pf added to list.
# wilmington, us added to list.
# torbay, ca added to list.
# kapaa, us added to list.
# saleaula, ws added to list.
# monrovia, lr added to list.
# grand river south east, mu added to list.
# tura, ru added to list.
# marawi, sd added to list.
# hobart, au added to list.
# jamestown, sh added to list.
# carnarvon, au added to list.
# ancud, cl added to list.
# jumla, np added to list.
# oranjestad, aw added to list.
# lebu, cl added to list.
# bredasdorp, za added to list.
# tiksi, ru added to list.
# blagoyevo, ru added to list.
# tuktoyaktuk, ca added to list.
# taburi, ph added to list.
# mecca, sa added to list.
# bengkulu, id added to list.
# esil, kz added to list.
# ahuimanu, us added to list.
# mys shmidta, ru added to list.
# stephenville, ca added to list.
# bollnas, se added to list.
# ambilobe, mg added to list.
# tonj, sd added to list.
# tessalit, ml added to list.
# komsomolskiy, ru added to list.
# grand gaube, mu added to list.
# mar del plata, ar added to list.
# port lincoln, au added to list.
# ust-koksa, ru added to list.
# shirokiy, ru added to list.
# omboue, ga added to list.
# barawe, so added to list.
# salalah, om added to list.
# assai, br added to list.
# belushya guba, ru added to list.
# padang, id added to list.
# thompson, ca added to list.
# upernavik, gl added to list.
# jasrana, in added to list.
# mahebourg, mu added to list.
# geraldton, ca added to list.
# ilulissat, gl added to list.
# minot, us added to list.
# port hardy, ca added to list.
# butaritari, ki added to list.
# makubetsu, jp added to list.
# nelson bay, au added to list.
# port-gentil, ga added to list.
# illoqqortoormiut, gl added to list.
# plettenberg bay, za added to list.
# saint-augustin, ca added to list.
# bubaque, gw added to list.
# castro, cl added to list.
# kirensk, ru added to list.
# kapit, my added to list.
# amderma, ru added to list.
# santiago de cao, pe added to list.
# beringovskiy, ru added to list.
# wadi, in added to list.
# kirovskiy, ru added to list.
# paka, my added to list.
# yaan, cn added to list.
# noyabrsk, ru added to list.
# hofn, is added to list.
# aklavik, ca added to list.
# pangody, ru added to list.
# constitucion, mx added to list.
# valdivia, co added to list.
# victoria, sc added to list.
# airai, pw added to list.
# dingle, ie added to list.
# wuwei, cn added to list.
# pevek, ru added to list.
# papara, pf added to list.
# adrar, dz added to list.
# ziarat, pk added to list.
# arraial do cabo, br added to list.
# berdigestyakh, ru added to list.
# chuy, uy added to list.
# vardo, no added to list.
# hilo, us added to list.
# khatanga, ru added to list.
# ginda, er added to list.
# kalomo, zm added to list.
# vestmanna, fo added to list.
# cockburn town, tc added to list.
# shatrovo, ru added to list.
# havre-saint-pierre, ca added to list.
# brigantine, us added to list.
# pacific grove, us added to list.
# taoudenni, ml added to list.
# ranong, th added to list.
# necochea, ar added to list.
# iqaluit, ca added to list.
# burnie, au added to list.
# ketchikan, us added to list.
# pilar, ph added to list.
# mareeba, au added to list.
# klaksvik, fo added to list.
# ternate, id added to list.
# hamina, fi added to list.
# qaanaaq, gl added to list.
# paamiut, gl added to list.
# asind, in added to list.
# hithadhoo, mv added to list.
# treinta y tres, uy added to list.
# healdsburg, us added to list.
# turukhansk, ru added to list.
# nemuro, jp added to list.
# santiago del estero, ar added to list.
# sucua, ec added to list.
# sao miguel do araguaia, br added to list.
# roald, no added to list.
# north auburn, us added to list.
# leningradskiy, ru added to list.
# hermanus, za added to list.
# xinyu, cn added to list.
# saldanha, za added to list.
# acapulco, mx added to list.
# changtu, cn added to list.
# sorland, no added to list.
# mount isa, au added to list.
# port augusta, au added to list.
# bay roberts, ca added to list.
# rudnogorsk, ru added to list.
# falealupo, ws added to list.
# veshenskaya, ru added to list.
# pundaguitan, ph added to list.
# opuwo, na added to list.
# lata, sb added to list.
# hoa binh, vn added to list.
# longyearbyen, sj added to list.
# fairbanks, us added to list.
# kaitangata, nz added to list.
# atyrau, kz added to list.
# esperance, au added to list.
# severo-kurilsk, ru added to list.
# ribeira grande, pt added to list.
# san quintin, mx added to list.
# attawapiskat, ca added to list.
# aksarka, ru added to list.
# charters towers, au added to list.
# kroya, id added to list.
# killarney, ca added to list.
# puri, in added to list.
# acajutla, sv added to list.
# kununurra, au added to list.
# naze, jp added to list.
# pisco, pe added to list.
# kiunga, pg added to list.
# aykhal, ru added to list.
# lagos, pt added to list.
# palabuhanratu, id added to list.
# cabo san lucas, mx added to list.
# ponta do sol, cv added to list.
# ngukurr, au added to list.
# coihaique, cl added to list.
# bose, cn added to list.
# cabedelo, br added to list.
# algiers, dz added to list.
# yellowknife, ca added to list.
# chunskiy, ru added to list.
# patin-ay, ph added to list.
# cayenne, gf added to list.
# dikson, ru added to list.
# barrow, us added to list.
# olmos, pe added to list.
# kavieng, pg added to list.
# xiongyue, cn added to list.
# bathsheba, bb added to list.
# caravelas, br added to list.
# peniche, pt added to list.
# north bend, us added to list.
# vaitupu, wf added to list.
# kruisfontein, za added to list.
# katsuura, jp added to list.
# kamina, cd added to list.
# dumai, id added to list.
# parrita, cr added to list.
# mergui, mm added to list.
# vao, nc added to list.
# yar-sale, ru added to list.
# betare oya, cm added to list.
# port-cartier, ca added to list.
# kenai, us added to list.
# longlac, ca added to list.
# kavaratti, in added to list.
# guiren, cn added to list.
# isoka, zm added to list.
# agbor, ng added to list.
# talnakh, ru added to list.
# kongwa, tz added to list.
# kampene, cd added to list.
# grindavik, is added to list.
# boa vista, br added to list.
# cidreira, br added to list.
# poya, nc added to list.
# saint george, bm added to list.
# san juan, ar added to list.
# cap malheureux, mu added to list.
# ostrovnoy, ru added to list.
# litovko, ru added to list.
# samusu, ws added to list.
# bahia honda, cu added to list.
# lagoa, pt added to list.
# lourdes, fr added to list.
# leh, in added to list.
# atambua, id added to list.
# siavonga, zm added to list.
# gravdal, no added to list.
# menongue, ao added to list.
# itupiranga, br added to list.
# imbituba, br added to list.
# provideniya, ru added to list.
# skalistyy, ru added to list.
# quetta, pk added to list.
# luan, cn added to list.
# jalu, ly added to list.
# laguna, br added to list.
# te anau, nz added to list.
# georgetown, sh added to list.
# saint-joseph, re added to list.
# solsvik, no added to list.
# portland, au added to list.
# bismarck, us added to list.
# deputatskiy, ru added to list.
# ponta do sol, pt added to list.
# ushtobe, kz added to list.
# marsh harbour, bs added to list.
# povenets, ru added to list.
# minas de barroteran, mx added to list.
# haines junction, ca added to list.
# nazas, mx added to list.
# sistranda, no added to list.
# panuco, mx added to list.
# mocorito, mx added to list.
# asau, tv added to list.
# tabuk, sa added to list.
# mandera, ke added to list.
# isangel, vu added to list.
# hirara, jp added to list.
# yulara, au added to list.
# tateyama, jp added to list.
# zambezi, zm added to list.
# talcahuano, cl added to list.
# severodvinsk, ru added to list.
# bethel, us added to list.
# mineros, bo added to list.
# brewster, us added to list.
# lephepe, bw added to list.
# henderson, us added to list.
# cocentaina, es added to list.
# canguaretama, br added to list.
# buin, pg added to list.
# mahadday weyne, so added to list.
# ishinomaki, jp added to list.
# consett, gb added to list.
# sabang, id added to list.
# oistins, bb added to list.
# megion, ru added to list.
# port keats, au added to list.
# durban, za added to list.
# road town, vg added to list.
# patancheru, in added to list.
# abu zabad, sd added to list.
# louisbourg, ca added to list.
# yellamanchili, in added to list.
# guiglo, ci added to list.
# chambersburg, us added to list.
# grand island, us added to list.
# alofi, nu added to list.
# kropotkin, ru added to list.
# tuatapere, nz added to list.
# rumford, us added to list.
# magadi, ke added to list.
# bay city, us added to list.
# sentyabrskiy, ru added to list.
# tenali, in added to list.
# angoram, pg added to list.
# nizhneyansk, ru added to list.
# chokurdakh, ru added to list.
# rocky mountain house, ca added to list.
# lichuan, cn added to list.
# havoysund, no added to list.
# nabire, id added to list.
# sena madureira, br added to list.
# joura, in added to list.
# kholtoson, ru added to list.
# kailua, us added to list.
# tubruq, ly added to list.
# harfleur, fr added to list.
# samarai, pg added to list.
# tagbac, ph added to list.
# ashland, us added to list.
# cururupu, br added to list.
# ocos, gt added to list.
# hasaki, jp added to list.
# sur, om added to list.
# huarmey, pe added to list.
# tecolutla, mx added to list.
# coquimbo, cl added to list.
# arkhangelskoye, ru added to list.
# atka, ru added to list.
# brae, gb added to list.
# souillac, mu added to list.
# sabratah, ly added to list.
# madison, us added to list.
# alma, us added to list.
# saryg-sep, ru added to list.
# ryotsu, jp added to list.
# samarinda, id added to list.
# lazaro cardenas, mx added to list.
# atar, mr added to list.
# teguldet, ru added to list.
# fare, pf added to list.
# kendari, id added to list.
# tsihombe, mg added to list.
# tarrafal, cv added to list.
# buraydah, sa added to list.
# oyama, jp added to list.
# nueva germania, py added to list.
# borlange, se added to list.
# rio brilhante, br added to list.
# hereford, us added to list.
# sterlibashevo, ru added to list.
# lamu, ke added to list.
# poykovskiy, ru added to list.
# nishihara, jp added to list.
# lodwar, ke added to list.
# naters, ch added to list.
# beloha, mg added to list.
# clyde river, ca added to list.
# bandarbeyla, so added to list.
# norman wells, ca added to list.
# auki, sb added to list.
# clovis, us added to list.
# biltine, td added to list.
# peleduy, ru added to list.
# kodiak, us added to list.
# georgiyevka, kz added to list.
# oranjemund, na added to list.
# toulepleu, ci added to list.
# nioro, ml added to list.
# makat, kz added to list.
# maltahohe, na added to list.
# harper, lr added to list.
# porto santo, pt added to list.
# udachnyy, ru added to list.
# kyzyl-suu, kg added to list.
# katherine, au added to list.
# cedar city, us added to list.
# tilichiki, ru added to list.
# nizwa, om added to list.
# usinsk, ru added to list.
# the valley, ai added to list.
# lenger, kz added to list.
# rochegda, ru added to list.
# severnyy-kospashskiy, ru added to list.
# edeia, br added to list.
# hella, is added to list.
# thames, nz added to list.
# yining, cn added to list.
# arman, ru added to list.
# lavrentiya, ru added to list.
# margate, za added to list.
# santa fe, pa added to list.
# fukue, jp added to list.
# abu samrah, qa added to list.
# rungata, ki added to list.
# inirida, co added to list.
# noumea, nc added to list.
# narsaq, gl added to list.
# djibo, bf added to list.
# villacarrillo, es added to list.
# larsnes, no added to list.
# dolbeau, ca added to list.
# blonduos, is added to list.
# manta, ec added to list.
# williams lake, ca added to list.
# tumannyy, ru added to list.
# darnah, ly added to list.
# correntina, br added to list.
# nikolskoye, ru added to list.
# umm lajj, sa added to list.
# tazovskiy, ru added to list.
# outjo, na added to list.
# vila velha, br added to list.
# maniitsoq, gl added to list.
# port elizabeth, za added to list.
# kahului, us added to list.
# saravena, co added to list.
# celestun, mx added to list.
# half moon bay, us added to list.
# batagay-alyta, ru added to list.
# hohhot, cn added to list.
# dhidhdhoo, mv added to list.
# qasigiannguit, gl added to list.
# little chute, us added to list.
# suoyarvi, ru added to list.
# rawson, ar added to list.
# belyy yar, ru added to list.
# surt, ly added to list.
# sao joao da barra, br added to list.
# huangchuan, cn added to list.
# anadyr, ru added to list.
# creel, mx added to list.
# camana, pe added to list.
# lithgow, au added to list.
# trat, th added to list.
# saint-pierre, pm added to list.
# portobelo, pa added to list.
# berlevag, no added to list.
# yataity del norte, py added to list.
# dergachi, ru added to list.
# impfondo, cg added to list.
# euclid, us added to list.
# maxixe, mz added to list.
# ust-kuyga, ru added to list.
# verkhnevilyuysk, ru added to list.
# denpasar, id added to list.
# bertoua, cm added to list.
# ixtapa, mx added to list.
# eyl, so added to list.
# poum, nc added to list.
# niono, ml added to list.
# yangambi, cd added to list.
# ashqelon, il added to list.
# matagami, ca added to list.
# praya, id added to list.
# mount gambier, au added to list.
# djenne, ml added to list.
# magadan, ru added to list.
# jacareacanga, br added to list.
# bozeman, us added to list.
# kaili, cn added to list.
# alexandria, eg added to list.
# luderitz, na added to list.
# korcula, hr added to list.
# cherskiy, ru added to list.
# altay, cn added to list.
# marcona, pe added to list.
# molokovo, ru added to list.
# la fleche, fr added to list.
# kasongo-lunda, cd added to list.
# paez, co added to list.
# mackay, au added to list.
# port blair, in added to list.
# port hedland, au added to list.
# karamea, nz added to list.
# bara, sd added to list.
# limbang, my added to list.
# mukhtolovo, ru added to list.
# yeppoon, au added to list.
# baglung, np added to list.
# fort nelson, ca added to list.
# goderich, sl added to list.
# barreirinhas, br added to list.
# gasa, bt added to list.
# abnub, eg added to list.
# bonavista, ca added to list.
# kabinda, cd added to list.
# halalo, wf added to list.
# pangnirtung, ca added to list.
# guasdualito, ve added to list.
# ambon, id added to list.
# susurluk, tr added to list.
# namatanai, pg added to list.
# kyrksaeterora, no added to list.
# ozgon, kg added to list.
# hualmay, pe added to list.
# tobol, kz added to list.
# thinadhoo, mv added to list.
# geraldton, au added to list.
# yarada, in added to list.
# krasnoselkup, ru added to list.
# eureka, us added to list.
# ankazoabo, mg added to list.
# gonbad-e qabus, ir added to list.
# ola, ru added to list.
# nanakuli, us added to list.
# polson, us added to list.
# muhoroni, ke added to list.
# kholodnyy, ru added to list.
# xadani, mx added to list.
# chagda, ru added to list.
# umm kaddadah, sd added to list.
# sohbatpur, pk added to list.
# xai-xai, mz added to list.
# akyab, mm added to list.
# camacha, pt added to list.
# neuquen, ar added to list.
# vitoria, es added to list.
# tahe, cn added to list.
# baherden, tm added to list.
# areosa, pt added to list.
# makakilo city, us added to list.
# killybegs, ie added to list.
# la ronge, ca added to list.
# uray, ru added to list.
# zabaykalsk, ru added to list.
# egvekinot, ru added to list.
# benghazi, ly added to list.
# birjand, ir added to list.
# makasar, id added to list.
# namibe, ao added to list.
# zhigansk, ru added to list.
# tarko-sale, ru added to list.
# palana, ru added to list.
# jujuy, ar added to list.
# lima, pe added to list.
# catalao, br added to list.
# insar, ru added to list.
# bergen, de added to list.
# manaure, co added to list.
# dvinskoy, ru added to list.
# gornozavodsk, ru added to list.
# karaul, ru added to list.
# asheboro, us added to list.
# kulhudhuffushi, mv added to list.
# bereda, so added to list.
# chernyshevskiy, ru added to list.
# turayf, sa added to list.
# zolotinka, ru added to list.
# formosa, br added to list.
# kiboga, ug added to list.
# port macquarie, au added to list.
# olafsvik, is added to list.
# parambu, br added to list.
# san patricio, mx added to list.
# balikpapan, id added to list.
# chicama, pe added to list.
# antofagasta, cl added to list.
# basco, ph added to list.
# soe, id added to list.
# grafton, au added to list.
# lodingen, no added to list.
# trinidad, bo added to list.
# yanchukan, ru added to list.
# elk point, ca added to list.
# kremenki, ru added to list.
# lompoc, us added to list.
# jyvaskyla, fi added to list.
# saint anthony, ca added to list.
# sao filipe, cv added to list.
# fredericksburg, us added to list.
# ulladulla, au added to list.
# kandrian, pg added to list.
# mollendo, pe added to list.
# emba, kz added to list.
# galiwinku, au added to list.
# kirakira, sb added to list.
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather = []
wrec = []
wrec = 1
url = 'http://api.openweathermap.org/data/2.5/weather?'
for x in cities:
    request = url + "appid=" + api_key + "&q=" + x + "?" + "&units=imperial"
    print(f"Processing record {wrec}: data for {x}")
    response = requests.get(request)
    weather_data = response.json()
    # skip errors
    if weather_data['cod'] == 200:
        weather.append(weather_data)
    # increase record count    
    wrec = wrec+1
# Out:
# Processing record 1: data for susanville, us
# Processing record 2: data for port alfred, za
# Processing record 3: data for rikitea, pf
# Processing record 4: data for korgen, no
# Processing record 5: data for albany, au
# Processing record 6: data for saskylakh, ru
# Processing record 7: data for arrifes, pt
# Processing record 8: data for east london, za
# Processing record 9: data for bambous virieux, mu
# Processing record 10: data for meyungs, pw
# Processing record 11: data for vila franca do campo, pt
# Processing record 12: data for codrington, ag
# Processing record 13: data for dothan, us
# Processing record 14: data for avarua, ck
# Processing record 15: data for saint-philippe, re
# Processing record 16: data for ushuaia, ar
# Processing record 17: data for vaini, to
# Processing record 18: data for rocha, uy
# Processing record 19: data for calatayud, es
# Processing record 20: data for atuona, pf
# Processing record 21: data for sechura, pe
# Processing record 22: data for montepuez, mz
# Processing record 23: data for new norfolk, au
# Processing record 24: data for barentsburg, sj
# Processing record 25: data for cape town, za
# Processing record 26: data for san cristobal, ec
# Processing record 27: data for punta arenas, cl
# Processing record 28: data for los llanos de aridane, es
# Processing record 29: data for bluff, nz
# Processing record 30: data for mataura, pf
# Processing record 31: data for nanortalik, gl
# Processing record 32: data for sitka, us
# Processing record 33: data for puerto ayora, ec
# Processing record 34: data for pedernales, do
# Processing record 35: data for ouango, cf
# Processing record 36: data for tasiilaq, gl
# Processing record 37: data for busselton, au
# Processing record 38: data for taolanaro, mg
# Processing record 39: data for vallenar, cl
# Processing record 40: data for hamilton, bm
# Processing record 41: data for govindgarh, in
# Processing record 42: data for nome, us
# Processing record 43: data for faanui, pf
# Processing record 44: data for wilmington, us
# Processing record 45: data for torbay, ca
# Processing record 46: data for kapaa, us
# Processing record 47: data for saleaula, ws
# Processing record 48: data for monrovia, lr
# Processing record 49: data for grand river south east, mu
# Processing record 50: data for tura, ru
# Processing record 51: data for marawi, sd
# Processing record 52: data for hobart, au
# Processing record 53: data for jamestown, sh
# Processing record 54: data for carnarvon, au
# Processing record 55: data for ancud, cl
# Processing record 56: data for jumla, np
# Processing record 57: data for oranjestad, aw
# Processing record 58: data for lebu, cl
# Processing record 59: data for bredasdorp, za
# Processing record 60: data for tiksi, ru
# Processing record 61: data for blagoyevo, ru
# Processing record 62: data for tuktoyaktuk, ca
# Processing record 63: data for taburi, ph
# Processing record 64: data for mecca, sa
# Processing record 65: data for bengkulu, id
# Processing record 66: data for esil, kz
# Processing record 67: data for ahuimanu, us
# Processing record 68: data for mys shmidta, ru
# Processing record 69: data for stephenville, ca
# Processing record 70: data for bollnas, se
# Processing record 71: data for ambilobe, mg
# Processing record 72: data for tonj, sd
# Processing record 73: data for tessalit, ml
# Processing record 74: data for komsomolskiy, ru
# Processing record 75: data for grand gaube, mu
# Processing record 76: data for mar del plata, ar
# Processing record 77: data for port lincoln, au
# Processing record 78: data for ust-koksa, ru
# Processing record 79: data for shirokiy, ru
# Processing record 80: data for omboue, ga
# Processing record 81: data for barawe, so
# Processing record 82: data for salalah, om
# Processing record 83: data for assai, br
# Processing record 84: data for belushya guba, ru
# Processing record 85: data for padang, id
# Processing record 86: data for thompson, ca
# Processing record 87: data for upernavik, gl
# Processing record 88: data for jasrana, in
# Processing record 89: data for mahebourg, mu
# Processing record 90: data for geraldton, ca
# Processing record 91: data for ilulissat, gl
# Processing record 92: data for minot, us
# Processing record 93: data for port hardy, ca
# Processing record 94: data for butaritari, ki
# Processing record 95: data for makubetsu, jp
# Processing record 96: data for nelson bay, au
# Processing record 97: data for port-gentil, ga
# Processing record 98: data for illoqqortoormiut, gl
# Processing record 99: data for plettenberg bay, za
# Processing record 100: data for saint-augustin, ca
# Processing record 101: data for bubaque, gw
# Processing record 102: data for castro, cl
# Processing record 103: data for kirensk, ru
# Processing record 104: data for kapit, my
# Processing record 105: data for amderma, ru
# Processing record 106: data for santiago de cao, pe
# Processing record 107: data for beringovskiy, ru
# Processing record 108: data for wadi, in
# Processing record 109: data for kirovskiy, ru
# Processing record 110: data for paka, my
# Processing record 111: data for yaan, cn
# Processing record 112: data for noyabrsk, ru
# Processing record 113: data for hofn, is
# Processing record 114: data for aklavik, ca
# Processing record 115: data for pangody, ru
# Processing record 116: data for constitucion, mx
# Processing record 117: data for valdivia, co
# Processing record 118: data for victoria, sc
# Processing record 119: data for airai, pw
# Processing record 120: data for dingle, ie
# Processing record 121: data for wuwei, cn
# Processing record 122: data for pevek, ru
# Processing record 123: data for papara, pf
# Processing record 124: data for adrar, dz
# Processing record 125: data for ziarat, pk
# Processing record 126: data for arraial do cabo, br
# Processing record 127: data for berdigestyakh, ru
# Processing record 128: data for chuy, uy
# Processing record 129: data for vardo, no
# Processing record 130: data for hilo, us
# Processing record 131: data for khatanga, ru
# Processing record 132: data for ginda, er
# Processing record 133: data for kalomo, zm
# Processing record 134: data for vestmanna, fo
# Processing record 135: data for cockburn town, tc
# Processing record 136: data for shatrovo, ru
# Processing record 137: data for havre-saint-pierre, ca
# Processing record 138: data for brigantine, us
# Processing record 139: data for pacific grove, us
# Processing record 140: data for taoudenni, ml
# Processing record 141: data for ranong, th
# Processing record 142: data for necochea, ar
# Processing record 143: data for iqaluit, ca
# Processing record 144: data for burnie, au
# Processing record 145: data for ketchikan, us
# Processing record 146: data for pilar, ph
# Processing record 147: data for mareeba, au
# Processing record 148: data for klaksvik, fo
# Processing record 149: data for ternate, id
# Processing record 150: data for hamina, fi
# Processing record 151: data for qaanaaq, gl
# Processing record 152: data for paamiut, gl
# Processing record 153: data for asind, in
# Processing record 154: data for hithadhoo, mv
# Processing record 155: data for treinta y tres, uy
# Processing record 156: data for healdsburg, us
# Processing record 157: data for turukhansk, ru
# Processing record 158: data for nemuro, jp
# Processing record 159: data for santiago del estero, ar
# Processing record 160: data for sucua, ec
# Processing record 161: data for sao miguel do araguaia, br
# Processing record 162: data for roald, no
# Processing record 163: data for north auburn, us
# Processing record 164: data for leningradskiy, ru
# Processing record 165: data for hermanus, za
# Processing record 166: data for xinyu, cn
# Processing record 167: data for saldanha, za
# Processing record 168: data for acapulco, mx
# Processing record 169: data for changtu, cn
# Processing record 170: data for sorland, no
# Processing record 171: data for mount isa, au
# Processing record 172: data for port augusta, au
# Processing record 173: data for bay roberts, ca
# Processing record 174: data for rudnogorsk, ru
# Processing record 175: data for falealupo, ws
# Processing record 176: data for veshenskaya, ru
# Processing record 177: data for pundaguitan, ph
# Processing record 178: data for opuwo, na
# Processing record 179: data for lata, sb
# Processing record 180: data for hoa binh, vn
# Processing record 181: data for longyearbyen, sj
# Processing record 182: data for fairbanks, us
# Processing record 183: data for kaitangata, nz
# Processing record 184: data for atyrau, kz
# Processing record 185: data for esperance, au
# Processing record 186: data for severo-kurilsk, ru
# Processing record 187: data for ribeira grande, pt
# Processing record 188: data for san quintin, mx
# Processing record 189: data for attawapiskat, ca
# Processing record 190: data for aksarka, ru
# Processing record 191: data for charters towers, au
# Processing record 192: data for kroya, id
# Processing record 193: data for killarney, ca
# Processing record 194: data for puri, in
# Processing record 195: data for acajutla, sv
# Processing record 196: data for kununurra, au
# Processing record 197: data for naze, jp
# Processing record 198: data for pisco, pe
# Processing record 199: data for kiunga, pg
# Processing record 200: data for aykhal, ru
# Processing record 201: data for lagos, pt
# Processing record 202: data for palabuhanratu, id
# Processing record 203: data for cabo san lucas, mx
# Processing record 204: data for ponta do sol, cv
# Processing record 205: data for ngukurr, au
# Processing record 206: data for coihaique, cl
# Processing record 207: data for bose, cn
# Processing record 208: data for cabedelo, br
# Processing record 209: data for algiers, dz
# Processing record 210: data for yellowknife, ca
# Processing record 211: data for chunskiy, ru
# Processing record 212: data for patin-ay, ph
# Processing record 213: data for cayenne, gf
# Processing record 214: data for dikson, ru
# Processing record 215: data for barrow, us
# Processing record 216: data for olmos, pe
# Processing record 217: data for kavieng, pg
# Processing record 218: data for xiongyue, cn
# Processing record 219: data for bathsheba, bb
# Processing record 220: data for caravelas, br
# Processing record 221: data for peniche, pt
# Processing record 222: data for north bend, us
# Processing record 223: data for vaitupu, wf
# Processing record 224: data for kruisfontein, za
# Processing record 225: data for katsuura, jp
# Processing record 226: data for kamina, cd
# Processing record 227: data for dumai, id
# Processing record 228: data for parrita, cr
# Processing record 229: data for mergui, mm
# Processing record 230: data for vao, nc
# Processing record 231: data for yar-sale, ru
# Processing record 232: data for betare oya, cm
# Processing record 233: data for port-cartier, ca
# Processing record 234: data for kenai, us
# Processing record 235: data for longlac, ca
# Processing record 236: data for kavaratti, in
# Processing record 237: data for guiren, cn
# Processing record 238: data for isoka, zm
# Processing record 239: data for agbor, ng
# Processing record 240: data for talnakh, ru
# Processing record 241: data for kongwa, tz
# Processing record 242: data for kampene, cd
# Processing record 243: data for grindavik, is
# Processing record 244: data for boa vista, br
# Processing record 245: data for cidreira, br
# Processing record 246: data for poya, nc
# Processing record 247: data for saint george, bm
# Processing record 248: data for san juan, ar
# Processing record 249: data for cap malheureux, mu
# Processing record 250: data for ostrovnoy, ru
# Processing record 251: data for litovko, ru
# Processing record 252: data for samusu, ws
# Processing record 253: data for bahia honda, cu
# Processing record 254: data for lagoa, pt
# Processing record 255: data for lourdes, fr
# Processing record 256: data for leh, in
# Processing record 257: data for atambua, id
# Processing record 258: data for siavonga, zm
# Processing record 259: data for gravdal, no
# Processing record 260: data for menongue, ao
# Processing record 261: data for itupiranga, br
# Processing record 262: data for imbituba, br
# Processing record 263: data for provideniya, ru
# Processing record 264: data for skalistyy, ru
# Processing record 265: data for quetta, pk
# Processing record 266: data for luan, cn
# Processing record 267: data for jalu, ly
# Processing record 268: data for laguna, br
# Processing record 269: data for te anau, nz
# Processing record 270: data for georgetown, sh
# Processing record 271: data for saint-joseph, re
# Processing record 272: data for solsvik, no
# Processing record 273: data for portland, au
# Processing record 274: data for bismarck, us
# Processing record 275: data for deputatskiy, ru
# Processing record 276: data for ponta do sol, pt
# Processing record 277: data for ushtobe, kz
# Processing record 278: data for marsh harbour, bs
# Processing record 279: data for povenets, ru
# Processing record 280: data for minas de barroteran, mx
# Processing record 281: data for haines junction, ca
# Processing record 282: data for nazas, mx
# Processing record 283: data for sistranda, no
# Processing record 284: data for panuco, mx
# Processing record 285: data for mocorito, mx
# Processing record 286: data for asau, tv
# Processing record 287: data for tabuk, sa
# Processing record 288: data for mandera, ke
# Processing record 289: data for isangel, vu
# Processing record 290: data for hirara, jp
# Processing record 291: data for yulara, au
# Processing record 292: data for tateyama, jp
# Processing record 293: data for zambezi, zm
# Processing record 294: data for talcahuano, cl
# Processing record 295: data for severodvinsk, ru
# Processing record 296: data for bethel, us
# Processing record 297: data for mineros, bo
# Processing record 298: data for brewster, us
# Processing record 299: data for lephepe, bw
# Processing record 300: data for henderson, us
# Processing record 301: data for cocentaina, es
# Processing record 302: data for canguaretama, br
# Processing record 303: data for buin, pg
# Processing record 304: data for mahadday weyne, so
# Processing record 305: data for ishinomaki, jp
# Processing record 306: data for consett, gb
# Processing record 307: data for sabang, id
# Processing record 308: data for oistins, bb
# Processing record 309: data for megion, ru
# Processing record 310: data for port keats, au
# Processing record 311: data for durban, za
# Processing record 312: data for road town, vg
# Processing record 313: data for patancheru, in
# Processing record 314: data for abu zabad, sd
# Processing record 315: data for louisbourg, ca
# Processing record 316: data for yellamanchili, in
# Processing record 317: data for guiglo, ci
# Processing record 318: data for chambersburg, us
# Processing record 319: data for grand island, us
# Processing record 320: data for alofi, nu
# Processing record 321: data for kropotkin, ru
# Processing record 322: data for tuatapere, nz
# Processing record 323: data for rumford, us
# Processing record 324: data for magadi, ke
# Processing record 325: data for bay city, us
# Processing record 326: data for sentyabrskiy, ru
# Processing record 327: data for tenali, in
# Processing record 328: data for angoram, pg
# Processing record 329: data for nizhneyansk, ru
# Processing record 330: data for chokurdakh, ru
# Processing record 331: data for rocky mountain house, ca
# Processing record 332: data for lichuan, cn
# Processing record 333: data for havoysund, no
# Processing record 334: data for nabire, id
# Processing record 335: data for sena madureira, br
# Processing record 336: data for joura, in
# Processing record 337: data for kholtoson, ru
# Processing record 338: data for kailua, us
# Processing record 339: data for tubruq, ly
# Processing record 340: data for harfleur, fr
# Processing record 341: data for samarai, pg
# Processing record 342: data for tagbac, ph
# Processing record 343: data for ashland, us
# Processing record 344: data for cururupu, br
# Processing record 345: data for ocos, gt
# Processing record 346: data for hasaki, jp
# Processing record 347: data for sur, om
# Processing record 348: data for huarmey, pe
# Processing record 349: data for tecolutla, mx
# Processing record 350: data for coquimbo, cl
# Processing record 351: data for arkhangelskoye, ru
# Processing record 352: data for atka, ru
# Processing record 353: data for brae, gb
# Processing record 354: data for souillac, mu
# Processing record 355: data for sabratah, ly
# Processing record 356: data for madison, us
# Processing record 357: data for alma, us
# Processing record 358: data for saryg-sep, ru
# Processing record 359: data for ryotsu, jp
# Processing record 360: data for samarinda, id
# Processing record 361: data for lazaro cardenas, mx
# Processing record 362: data for atar, mr
# Processing record 363: data for teguldet, ru
# Processing record 364: data for fare, pf
# Processing record 365: data for kendari, id
# Processing record 366: data for tsihombe, mg
# Processing record 367: data for tarrafal, cv
# Processing record 368: data for buraydah, sa
# Processing record 369: data for oyama, jp
# Processing record 370: data for nueva germania, py
# Processing record 371: data for borlange, se
# Processing record 372: data for rio brilhante, br
# Processing record 373: data for hereford, us
# Processing record 374: data for sterlibashevo, ru
# Processing record 375: data for lamu, ke
# Processing record 376: data for poykovskiy, ru
# Processing record 377: data for nishihara, jp
# Processing record 378: data for lodwar, ke
# Processing record 379: data for naters, ch
# Processing record 380: data for beloha, mg
# Processing record 381: data for clyde river, ca
# Processing record 382: data for bandarbeyla, so
# Processing record 383: data for norman wells, ca
# Processing record 384: data for auki, sb
# Processing record 385: data for clovis, us
# Processing record 386: data for biltine, td
# Processing record 387: data for peleduy, ru
# Processing record 388: data for kodiak, us
# Processing record 389: data for georgiyevka, kz
# Processing record 390: data for oranjemund, na
# Processing record 391: data for toulepleu, ci
# Processing record 392: data for nioro, ml
# Processing record 393: data for makat, kz
# Processing record 394: data for maltahohe, na
# Processing record 395: data for harper, lr
# Processing record 396: data for porto santo, pt
# Processing record 397: data for udachnyy, ru
# Processing record 398: data for kyzyl-suu, kg
# Processing record 399: data for katherine, au
# Processing record 400: data for cedar city, us
# Processing record 401: data for tilichiki, ru
# Processing record 402: data for nizwa, om
# Processing record 403: data for usinsk, ru
# Processing record 404: data for the valley, ai
# Processing record 405: data for lenger, kz
# Processing record 406: data for rochegda, ru
# Processing record 407: data for severnyy-kospashskiy, ru
# Processing record 408: data for edeia, br
# Processing record 409: data for hella, is
# Processing record 410: data for thames, nz
# Processing record 411: data for yining, cn
# Processing record 412: data for arman, ru
# Processing record 413: data for lavrentiya, ru
# Processing record 414: data for margate, za
# Processing record 415: data for santa fe, pa
# Processing record 416: data for fukue, jp
# Processing record 417: data for abu samrah, qa
# Processing record 418: data for rungata, ki
# Processing record 419: data for inirida, co
# Processing record 420: data for noumea, nc
# Processing record 421: data for narsaq, gl
# Processing record 422: data for djibo, bf
# Processing record 423: data for villacarrillo, es
# Processing record 424: data for larsnes, no
# Processing record 425: data for dolbeau, ca
# Processing record 426: data for blonduos, is
# Processing record 427: data for manta, ec
# Processing record 428: data for williams lake, ca
# Processing record 429: data for tumannyy, ru
# Processing record 430: data for darnah, ly
# Processing record 431: data for correntina, br
# Processing record 432: data for nikolskoye, ru
# Processing record 433: data for umm lajj, sa
# Processing record 434: data for tazovskiy, ru
# Processing record 435: data for outjo, na
# Processing record 436: data for vila velha, br
# Processing record 437: data for maniitsoq, gl
# Processing record 438: data for port elizabeth, za
# Processing record 439: data for kahului, us
# Processing record 440: data for saravena, co
# Processing record 441: data for celestun, mx
# Processing record 442: data for half moon bay, us
# Processing record 443: data for batagay-alyta, ru
# Processing record 444: data for hohhot, cn
# Processing record 445: data for dhidhdhoo, mv
# Processing record 446: data for qasigiannguit, gl
# Processing record 447: data for little chute, us
# Processing record 448: data for suoyarvi, ru
# Processing record 449: data for rawson, ar
# Processing record 450: data for belyy yar, ru
# Processing record 451: data for surt, ly
# Processing record 452: data for sao joao da barra, br
# Processing record 453: data for huangchuan, cn
# Processing record 454: data for anadyr, ru
# Processing record 455: data for creel, mx
# Processing record 456: data for camana, pe
# Processing record 457: data for lithgow, au
# Processing record 458: data for trat, th
# Processing record 459: data for saint-pierre, pm
# Processing record 460: data for portobelo, pa
# Processing record 461: data for berlevag, no
# Processing record 462: data for yataity del norte, py
# Processing record 463: data for dergachi, ru
# Processing record 464: data for impfondo, cg
# Processing record 465: data for euclid, us
# Processing record 466: data for maxixe, mz
# Processing record 467: data for ust-kuyga, ru
# Processing record 468: data for verkhnevilyuysk, ru
# Processing record 469: data for denpasar, id
# Processing record 470: data for bertoua, cm
# Processing record 471: data for ixtapa, mx
# Processing record 472: data for eyl, so
# Processing record 473: data for poum, nc
# Processing record 474: data for niono, ml
# Processing record 475: data for yangambi, cd
# Processing record 476: data for ashqelon, il
# Processing record 477: data for matagami, ca
# Processing record 478: data for praya, id
# Processing record 479: data for mount gambier, au
# Processing record 480: data for djenne, ml
# Processing record 481: data for magadan, ru
# Processing record 482: data for jacareacanga, br
# Processing record 483: data for bozeman, us
# Processing record 484: data for kaili, cn
# Processing record 485: data for alexandria, eg
# Processing record 486: data for luderitz, na
# Processing record 487: data for korcula, hr
# Processing record 488: data for cherskiy, ru
# Processing record 489: data for altay, cn
# Processing record 490: data for marcona, pe
# Processing record 491: data for molokovo, ru
# Processing record 492: data for la fleche, fr
# Processing record 493: data for kasongo-lunda, cd
# Processing record 494: data for paez, co
# Processing record 495: data for mackay, au
# Processing record 496: data for port blair, in
# Processing record 497: data for port hedland, au
# Processing record 498: data for karamea, nz
# Processing record 499: data for bara, sd
# Processing record 500: data for limbang, my
# Processing record 501: data for mukhtolovo, ru
# Processing record 502: data for yeppoon, au
# Processing record 503: data for baglung, np
# Processing record 504: data for fort nelson, ca
# Processing record 505: data for goderich, sl
# Processing record 506: data for barreirinhas, br
# Processing record 507: data for gasa, bt
# Processing record 508: data for abnub, eg
# Processing record 509: data for bonavista, ca
# Processing record 510: data for kabinda, cd
# Processing record 511: data for halalo, wf
# Processing record 512: data for pangnirtung, ca
# Processing record 513: data for guasdualito, ve
# Processing record 514: data for ambon, id
# Processing record 515: data for susurluk, tr
# Processing record 516: data for namatanai, pg
# Processing record 517: data for kyrksaeterora, no
# Processing record 518: data for ozgon, kg
# Processing record 519: data for hualmay, pe
# Processing record 520: data for tobol, kz
# Processing record 521: data for thinadhoo, mv
# Processing record 522: data for geraldton, au
# Processing record 523: data for yarada, in
# Processing record 524: data for krasnoselkup, ru
# Processing record 525: data for eureka, us
# Processing record 526: data for ankazoabo, mg
# Processing record 527: data for gonbad-e qabus, ir
# Processing record 528: data for ola, ru
# Processing record 529: data for nanakuli, us
# Processing record 530: data for polson, us
# Processing record 531: data for muhoroni, ke
# Processing record 532: data for kholodnyy, ru
# Processing record 533: data for xadani, mx
# Processing record 534: data for chagda, ru
# Processing record 535: data for umm kaddadah, sd
# Processing record 536: data for sohbatpur, pk
# Processing record 537: data for xai-xai, mz
# Processing record 538: data for akyab, mm
# Processing record 539: data for camacha, pt
# Processing record 540: data for neuquen, ar
# Processing record 541: data for vitoria, es
# Processing record 542: data for tahe, cn
# Processing record 543: data for baherden, tm
# Processing record 544: data for areosa, pt
# Processing record 545: data for makakilo city, us
# Processing record 546: data for killybegs, ie
# Processing record 547: data for la ronge, ca
# Processing record 548: data for uray, ru
# Processing record 549: data for zabaykalsk, ru
# Processing record 550: data for egvekinot, ru
# Processing record 551: data for benghazi, ly
# Processing record 552: data for birjand, ir
# Processing record 553: data for makasar, id
# Processing record 554: data for namibe, ao
# Processing record 555: data for zhigansk, ru
# Processing record 556: data for tarko-sale, ru
# Processing record 557: data for palana, ru
# Processing record 558: data for jujuy, ar
# Processing record 559: data for lima, pe
# Processing record 560: data for catalao, br
# Processing record 561: data for insar, ru
# Processing record 562: data for bergen, de
# Processing record 563: data for manaure, co
# Processing record 564: data for dvinskoy, ru
# Processing record 565: data for gornozavodsk, ru
# Processing record 566: data for karaul, ru
# Processing record 567: data for asheboro, us
# Processing record 568: data for kulhudhuffushi, mv
# Processing record 569: data for bereda, so
# Processing record 570: data for chernyshevskiy, ru
# Processing record 571: data for turayf, sa
# Processing record 572: data for zolotinka, ru
# Processing record 573: data for formosa, br
# Processing record 574: data for kiboga, ug
# Processing record 575: data for port macquarie, au
# Processing record 576: data for olafsvik, is
# Processing record 577: data for parambu, br
# Processing record 578: data for san patricio, mx
# Processing record 579: data for balikpapan, id
# Processing record 580: data for chicama, pe
# Processing record 581: data for antofagasta, cl
# Processing record 582: data for basco, ph
# Processing record 583: data for soe, id
# Processing record 584: data for grafton, au
# Processing record 585: data for lodingen, no
# Processing record 586: data for trinidad, bo
# Processing record 587: data for yanchukan, ru
# Processing record 588: data for elk point, ca
# Processing record 589: data for kremenki, ru
# Processing record 590: data for lompoc, us
# Processing record 591: data for jyvaskyla, fi
# Processing record 592: data for saint anthony, ca
# Processing record 593: data for sao filipe, cv
# Processing record 594: data for fredericksburg, us
# Processing record 595: data for ulladulla, au
# Processing record 596: data for kandrian, pg
# Processing record 597: data for mollendo, pe
# Processing record 598: data for emba, kz
# Processing record 599: data for galiwinku, au
# Processing record 600: data for kirakira, sb

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create empty lists for each column
city = []
country = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
date = []

# iterate through the data to fill the lists
for x in weather:
        city.append(x['name'])
        country.append(x['sys']['country'])
        lat.append(x["coord"]['lat'])
        lng.append(x["coord"]['lon'])
        max_temp.append(x['main']['temp_max'])
        humidity.append(x['main']['humidity'])
        cloudiness.append(x['clouds']['all'])
        wind_speed.append(x['wind']['speed'])
        date.append(x['dt'])
# create the dataframe from the lists
weather_df = pd.DataFrame({
    'city':city,
    'country':country,
    'lat':lat,
    'lng':lng, 
    "max_temp":max_temp, 
    "humidity":humidity, 
    "cloudiness":cloudiness, 
    "wind_speed":wind_speed, 
    "date":date 
})

weather_df[["lat", "lng", "max_temp", "humidity", "cloudiness", "wind_speed", "date"]] = weather_df[["lat", "lng", "max_temp", "humidity", "cloudiness", "wind_speed", "date"]].apply(pd.to_numeric)
weather_df = weather_df.reset_index()    
# write data to a CSV file and show the dataframe
# weather_df.to_csv('weather_data.csv', mode = 'w', index=False, header=True)
weather_df.head(10)
# weather_df.dtypes
# Out:
#    index                  city country      lat       lng  max_temp  humidity  \
# 0      0            Susanville      US  40.4163 -120.6530     71.60         6
# 1      1           Port Alfred      ZA -33.5906   26.8910     66.22        79
# 2      2               Rikitea      PF -23.1203 -134.9692     76.06        66
# 3      3                Korgen      NO  66.0771   13.8153     35.01        73
# 4      4                Albany      US  42.6001  -73.9662     57.99        86
# 5      5             Saskylakh      RU  71.9167  114.0833     23.45        88
# 6      6               Arrifes      PT  37.7667  -25.7000     57.20        72
# 7      7           East London      ZA -33.0153   27.9116     68.00        73
# 8      8       Bambous Virieux      MU -20.3428   57.7575     77.00        83
# 9      9  Vila Franca do Campo      PT  37.7167  -25.4333     57.20        72
#
#    cloudiness  wind_speed        date
# 0           1        3.44  1619655810
# 1          98        8.48  1619655836
# 2          41       10.02  1619655836
# 3          91        2.15  1619655836
# 4          96        2.82  1619655837
# 5          87        7.67  1619655837
# 6          75        3.44  1619655837
# 7         100        4.07  1619655838
# 8          75       11.50  1619655838
# 9          75        3.44  1619655838

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humid = weather_df['humidity'].max()
print(humid)
# no cities were above 100%, no action needed
# Out:
# 100

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['lat'], weather_df['max_temp'],color='blue',s=40, edgecolor='black')
plt.grid(which = 'both')
plt.title('City Latitude vs Max Temperature (F)')
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig('City Latitude vs Max Temperature (F).png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['lat'], weather_df['humidity'],color='blue',s=40, edgecolor='black')
plt.grid(which = 'both')
plt.title('City Latitude vs Humidity (%)')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig('City Latitude vs Humidity (%).png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['lat'], weather_df['cloudiness'],color='blue',s=40, edgecolor='black')
plt.grid(which = 'both')
plt.title('City Latitude vs Cloudiness (%)')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig('City Latitude vs Cloudiness (%).png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['lat'], weather_df['wind_speed'],color='blue',s=40, edgecolor='black')
plt.grid(which = 'both')
plt.title('City Latitude vs Wind Speed (mph)')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig('City Latitude vs Wind Speed (mph).png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
